# %% [markdown]
# ### Names Classification Results

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# @Date    : Mar-27-21 23:36
# @Author  : Kan HUANG (kan.huang@connect.ust.hk)

import pickle
import matplotlib.pyplot as plt

# %%
log_dir = "./assets/results/names"
path = os.path.join(log_dir, "all_losses.pickle")
with open(path, "rb") as f:
    all_losses = pickle.load(f)

# %%
plt.figure()
plt.plot(all_losses)
plt.title("Training loss")
plt.xlabel("Steps'00")
plt.ylabel("NIL loss")
plt.grid()
